# %% [markdown]
# Import Libraries

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import math

# %% [markdown]
# # Linear Functions equation: y = k * x (Output = Input × Multiplier)
#
# **Parameters**:
#
# *   k: constant multiplier (determines steepness)
# *   x: independent variable
# *   y: output
#
# If x increases, y increases proportionally.

# %%
k = 2
print("Linear function formula: y = k × x")
print(f"Lets assume: k = {k}\n")
# Out:
# Linear function formula: y = k × x
# Lets assume: k = 2

# %%
for x in [0, 1, 3, 5, 10]:
    y = k * x
    print(f"When x = {x:2} → y = {y}")
# Out:
# When x =  0 → y = 0
# When x =  1 → y = 2
# When x =  3 → y = 6
# When x =  5 → y = 10
# When x = 10 → y = 20

# %%
x_values = np.linspace(0, 10, 200)
y_values = k * x_values

# %%
plt.figure(figsize=(10, 6))
plt.plot(x_values, y_values, 'purple', linewidth=3, label=f'y = {k}x')
plt.axhline(0, color='black', linewidth=1)
plt.axvline(0, color='black', linewidth=1)
plt.xlabel('x', fontsize=12)
plt.ylabel('y', fontsize=12)
plt.title(f'Linear Function: y = {k}x', fontsize=16, pad=20)
plt.grid(True, alpha=0.3)
plt.legend(fontsize=12)
plt.tight_layout()
plt.show()

# %%
# Different values of k
x = np.linspace(-5, 5, 400)
k_values = [2, 1, 0.5, -1, -2]

for k in [1, 2, 3, 0.5, -1]:
    plt.plot(x, k*x, label=f'y={k}x')

plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# # Quadratic Functions: y = x²
# The output is the square of the input number. If x = 2, then y = 4

# %%
# for x in [-4, -2, -1, 0, 1, 2, 3, 5]:
#     print(f"x = {x:>3}  →  x² = {x**2}")

# %%
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 12

# %%
# Data
x_values = np.linspace(-5, 5, 400)
y_values = x_values ** 2

# %%
# Create the plot
fig, ax = plt.subplots()

# Plot the parabola
ax.plot(x_values, y_values,
        color='#1f77b4',
        linewidth=3.5,
        label='$y = x^2$',
        zorder=5)

# Fill under the curve
ax.fill_between(x_values, y_values, alpha=0.2, color='#1f77b4')

# Highlight the vertex
ax.plot(0, 0, 'o', color='#ff7f0e', markersize=10, label='Vertex (0,0)', zorder=6)
ax.annotate('Vertex (0,0)', xy=(0, 0), xytext=(1, 3),
            arrowprops=dict(arrowstyle='->', color='gray', lw=1.5),
            fontsize=10, color='darkred', ha='right')

ax.set_title('Quadratic Function: $y = x^2$', fontsize=18, pad=20, fontweight='bold')
ax.set_xlabel('$x$', fontsize=14)
ax.set_ylabel('$y$', fontsize=14)
ax.set_xlim(-5, 5)
ax.set_ylim(-1, 25)

ax.grid(True, alpha=0.4)
ax.spines[['top', 'right']].set_visible(False)

example_x = [-3, -2, -1, 0, 1, 2, 3]
example_y = [x**2 for x in example_x]
ax.scatter(example_x, example_y, color='crimson', s=80, zorder=7, edgecolors='white', linewidth=1.5)
for x_val in example_x:
    if x_val != 0:
        y_val = x_val**2
        ax.annotate(f'({x_val}, {y_val})',
                    xy=(x_val, y_val), xytext=(x_val + 0.4, y_val + 2),
                    fontsize=10, alpha=0.9)

ax.legend(fontsize=12, loc='upper center', frameon=True, fancybox=True, shadow=True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Cubic Functions: y = x³
#
# For each x, calculate x³. If x = 2, then y = 8

# %%
examples = [-3, -2, -1, 0, 1, 2, 3]
for x in examples:
    y = x ** 3
    print(f"When x = {x}, y = x³ = {y}")

# Plot it
x_values = np.linspace(-3, 3, 100)
y_values = x_values ** 3

plt.figure(figsize=(8, 5))
plt.plot(x_values, y_values, 'b-', linewidth=2, label='y = x³')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Cubic Function: y = x³')
plt.grid(True)
plt.legend()
plt.axhline(y=0, color='k', linewidth=0.5)
plt.axvline(x=0, color='k', linewidth=0.5)
plt.show()
# Out:
# When x = -3, y = x³ = -27
# When x = -2, y = x³ = -8
# When x = -1, y = x³ = -1
# When x = 0, y = x³ = 0
# When x = 1, y = x³ = 1
# When x = 2, y = x³ = 8
# When x = 3, y = x³ = 27

# %% [markdown]
# # Square Root Function: y = √x
# The opposite of squaring. If x = 4, then y = 2

# %%
examples = [0, 1, 4, 9, 16, 25]
for x in examples:
    y = np.sqrt(x)
    print(f"When x = {x}, y = √{x} = {y}")

# Plot it
x_values = np.linspace(0, 25, 100)
y_values = np.sqrt(x_values)

plt.figure(figsize=(8, 5))
plt.plot(x_values, y_values, 'm-', linewidth=2, label='y = √x')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Square Root Function: y = √x')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# When x = 0, y = √0 = 0.0
# When x = 1, y = √1 = 1.0
# When x = 4, y = √4 = 2.0
# When x = 9, y = √9 = 3.0
# When x = 16, y = √16 = 4.0
# When x = 25, y = √25 = 5.0

# %% [markdown]
# # Exponential Function: y = 2^x
# Double the result each time x increases by 1. If x = 1, then y = 2. If x = 2, then y = 4.

# %%
examples = [0, 1, 2, 3, 4, 5]
for x in examples:
    y = 2 ** x
    print(f"When x = {x}, y = 2^{x} = {y}")

# Plot it
x_values = np.linspace(-2, 5, 100)
y_values = 2 ** x_values

plt.figure(figsize=(8, 5))
plt.plot(x_values, y_values, 'c-', linewidth=2, label='y = 2^x')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Exponential Function: y = 2^x')
plt.grid(True)
plt.legend()
plt.axhline(y=0, color='k', linewidth=0.5)
plt.axvline(x=0, color='k', linewidth=0.5)
plt.show()
# Out:
# When x = 0, y = 2^0 = 1
# When x = 1, y = 2^1 = 2
# When x = 2, y = 2^2 = 4
# When x = 3, y = 2^3 = 8
# When x = 4, y = 2^4 = 16
# When x = 5, y = 2^5 = 32

# %% [markdown]
# # Sine Function: y = sin(x)
# A wavy function that repeats. Used for waves, circles, and oscillations.

# %%
examples = [0, math.pi/2, math.pi, 3*math.pi/2, 2*math.pi]
for x in examples:
    y = math.sin(x)
    print(f"When x = {x:.2f}, y = sin(x) = {y:.2f}")

# Plot it
x_values = np.linspace(0, 4*np.pi, 100)
y_values = np.sin(x_values)

plt.figure(figsize=(10, 5))
plt.plot(x_values, y_values, 'orange', linewidth=2, label='y = sin(x)')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Sine Function: y = sin(x)')
plt.grid(True)
plt.legend()
plt.axhline(y=0, color='k', linewidth=0.5)
plt.show()
# Out:
# When x = 0.00, y = sin(x) = 0.00
# When x = 1.57, y = sin(x) = 1.00
# When x = 3.14, y = sin(x) = 0.00
# When x = 4.71, y = sin(x) = -1.00
# When x = 6.28, y = sin(x) = -0.00

# %% [markdown]
# # Combined Functions: y = 2x + 3
# You can combine operations! Multiply x by 2, then add 3

# %%
examples = [0, 1, 2, 3, 4]
for x in examples:
    y = 2 * x + 3
    print(f"When x = {x}, y = 2({x}) + 3 = {y}")

# Plot it
x_values = np.linspace(-5, 5, 100)
y_values = 2 * x_values + 3

plt.figure(figsize=(8, 5))
plt.plot(x_values, y_values, 'purple', linewidth=2, label='y = 2x + 3')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Combined Function: y = 2x + 3')
plt.grid(True)
plt.legend()
plt.axhline(y=0, color='k', linewidth=0.5)
plt.axvline(x=0, color='k', linewidth=0.5)
plt.show()
# Out:
# When x = 0, y = 2(0) + 3 = 3
# When x = 1, y = 2(1) + 3 = 5
# When x = 2, y = 2(2) + 3 = 7
# When x = 3, y = 2(3) + 3 = 9
# When x = 4, y = 2(4) + 3 = 11

# %% [markdown]
# # Summary: Compare All Functions
# Let's see how different functions look together!

# %%
x = np.linspace(0, 5, 100)

plt.figure(figsize=(12, 8))

# Linear
plt.subplot(2, 2, 1)
plt.plot(x, 2*x, 'b-', linewidth=2)
plt.title('y = 2x (Linear)')
plt.grid(True)

# Quadratic
plt.subplot(2, 2, 2)
plt.plot(x, x**2, 'r-', linewidth=2)
plt.title('y = x² (Quadratic)')
plt.grid(True)

# Exponential
plt.subplot(2, 2, 3)
plt.plot(x, 2**x, 'g-', linewidth=2)
plt.title('y = 2^x (Exponential)')
plt.grid(True)

# Square root
plt.subplot(2, 2, 4)
plt.plot(x, np.sqrt(x), 'm-', linewidth=2)
plt.title('y = √x (Square Root)')
plt.grid(True)

plt.tight_layout()
plt.show()
